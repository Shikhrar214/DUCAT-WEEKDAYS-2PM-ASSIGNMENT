# %% [markdown]
# ## Question 1

# %%
first_name = "Shikhar"
last_name = "Srivastav"
print(first_name + " " + last_name)
# Out:
# Shikhar Srivastav

# %% [markdown]
# ## Question 2

# %%
first_name = "Shikhar"
last_name = "Srivastav"
print(first_name+ " " + last_name)

print(first_name.join(last_name))
# Out:
# Shikhar Srivastav
# SShikharrShikhariShikharvShikharaShikharsShikhartShikharaShikharv

# %% [markdown]
# ## Question 3

# %%
text = "Shikhar"
print(text[0])
print(text[1])
print(text[2])
# Out:
# S
# h
# i

# %% [markdown]
# ## Question 4

# %%
text = "Shikhar"
print(len(text))
# Out:
# 7

# %% [markdown]
# ## Question 5

# %%
text = "Shikhar"
print(text.upper())
# Out:
# SHIKHAR

# %% [markdown]
# ## Question 6

# %%
text = "Shikhar"
print(text.lower())
# Out:
# shikhar

# %% [markdown]
# ## Question 7

# %%
text = "Shikhar"
print(text.replace("Shikhar", "Srivastav"))
# Out:
# Srivastav

# %% [markdown]
# ## Question 8

# %%
text = "My name is Shikhar Srivastav"
print(text.split(' '))
# Out:
# ['My', 'name', 'is', 'Shikhar', 'Srivastav']

# %% [markdown]
# ## Question 9

# %%
text = "Shikhar"
print(text.startswith("S"))
print(text.startswith("h"))
# Out:
# True
# False

# %% [markdown]
# ## Question 10

# %%
text = "Shikhar"
print(text.endswith("S"))
print(text.endswith("r"))
# Out:
# False
# True

# %% [markdown]
# ## Question 11

# %%
text = "   Shikhar  "
print(text.lstrip())
print(text.rstrip())
# Out:
# Shikhar
#    Shikhar

# %% [markdown]
# ## Question 12

# %%
text = "Shikhar"
print(text.index("S"))
print(text.index("r"))
# Out:
# 0
# 6

# %% [markdown]
# ## Question 13

# %%
text = "Shikhar"
print(text.count("h"))
print(text.count("r"))
# Out:
# 2
# 1

# %% [markdown]
# ## Question 14

# %%
text = "Shikhar"
print(text.isalpha())
# Out:
# True

# %% [markdown]
# ## Question 15

# %%
text = "123"
print(text.isnumeric())
# Out:
# True

# %% [markdown]
# ## Question 16

# %%
text = "12321"

if(text[::-1] == text):
    print("string is palindrome")
else:
    print("string is not palindrome")
# Out:
# string is palindrome

# %% [markdown]
# ## Question 17

# %%
text = "Shikhar"
print(text[::-1])
# Out:
# rahkihS

# %% [markdown]
# ## Question 18

# %%
first_name = "Shikhar"
last_name = "Srivastav"

print(f"my name is {first_name}  {last_name}" )
# Out:
# my name is Shikhar  Srivastav

# %% [markdown]
# ## Question 19

# %%
text = ("a", "b", "c", "d", "e", "f", "g", "h")
print(text[slice(2)])
print(text[slice(4)])
# Out:
# ('a', 'b')
# ('a', 'b', 'c', 'd')

# %% [markdown]
# ## Question 20

# %%
text = "Shikhar"
print(text.replace("i", ""))
print(text.removeprefix("S"))
print(text.removesuffix("r"))
# Out:
# Shkhar
# hikhar
# Shikha
